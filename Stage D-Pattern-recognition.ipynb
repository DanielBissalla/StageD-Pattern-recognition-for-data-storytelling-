# %%
import pandas as pd
import numpy as np

# %%
fprod=pd.read_csv('Africa Food Production (2004 - 2013).csv')

# %%
fprod
# Out:
#         Country                Item  Year  Value
# 0       Algeria  Wheat and products  2004   2731
# 1       Algeria  Wheat and products  2005   2415
# 2       Algeria  Wheat and products  2006   2688
# 3       Algeria  Wheat and products  2007   2319
# 4       Algeria  Wheat and products  2008   1111
# ...         ...                 ...   ...    ...
# 23105  Zimbabwe         Crustaceans  2009      0
# 23106  Zimbabwe         Crustaceans  2010      0
# 23107  Zimbabwe         Crustaceans  2011      0
# 23108  Zimbabwe         Crustaceans  2012      0
# 23109  Zimbabwe         Crustaceans  2013      0
#
# [23110 rows x 4 columns]

# %%
#from datetime import datetime
#fprod['Year']=pd.to_datetime(fprod['Year'], infer_datetime_format=True)

# %%
fprod['Value'].apply(lambda x:str(x)+ 'kt')
# Out:
# 0        2731kt
# 1        2415kt
# 2        2688kt
# 3        2319kt
# 4        1111kt
#           ...
# 23105       0kt
# 23106       0kt
# 23107       0kt
# 23108       0kt
# 23109       0kt
# Name: Value, Length: 23110, dtype: object

# %%
fprod['Value']=fprod['Value'].apply(lambda x:str(x)+ 'kt')

# %%
fprod
# Out:
#         Country                Item  Year   Value
# 0       Algeria  Wheat and products  2004  2731kt
# 1       Algeria  Wheat and products  2005  2415kt
# 2       Algeria  Wheat and products  2006  2688kt
# 3       Algeria  Wheat and products  2007  2319kt
# 4       Algeria  Wheat and products  2008  1111kt
# ...         ...                 ...   ...     ...
# 23105  Zimbabwe         Crustaceans  2009     0kt
# 23106  Zimbabwe         Crustaceans  2010     0kt
# 23107  Zimbabwe         Crustaceans  2011     0kt
# 23108  Zimbabwe         Crustaceans  2012     0kt
# 23109  Zimbabwe         Crustaceans  2013     0kt
#
# [23110 rows x 4 columns]

# %%
fprod.groupby(['Country', 'Year', 'Item'])

# %%
fprod['Year'].value_counts()
# Out:
# 2004    2312
# 2005    2312
# 2006    2312
# 2007    2312
# 2008    2312
# 2009    2312
# 2010    2312
# 2011    2312
# 2012    2307
# 2013    2307
# Name: Year, dtype: int64

# %%
country_grp=fprod.groupby(['Country'])

# %%
country_grp['Item'].value_counts().loc['Algeria']
# Out:
# Item
# Apples and products                10
# Bananas                            10
# Barley and products                10
# Beans                              10
# Beer                               10
# Beverages, Alcoholic               10
# Bovine Meat                        10
# Butter, Ghee                       10
# Cephalopods                        10
# Cereals, Other                     10
# Citrus, Other                      10
# Cottonseed                         10
# Crustaceans                        10
# Dates                              10
# Demersal Fish                      10
# Eggs                               10
# Fats, Animals, Raw                 10
# Freshwater Fish                    10
# Fruits, Other                      10
# Grapefruit and products            10
# Grapes and products (excl wine)    10
# Groundnut Oil                      10
# Groundnuts (Shelled Eq)            10
# Honey                              10
# ...

# %%
country_grp['Item'].value_counts().loc['Nigeria']
# Out:
# Item
# Beer                     10
# Beverages, Fermented     10
# Bovine Meat              10
# Butter, Ghee             10
# Cassava and products     10
#                          ..
# Sweet potatoes           10
# Tomatoes and products    10
# Vegetables, Other        10
# Wheat and products       10
# Yams                     10
# Name: Item, Length: 61, dtype: int64

# %%
fprod['Country']
# Out:
# 0         Algeria
# 1         Algeria
# 2         Algeria
# 3         Algeria
# 4         Algeria
#            ...
# 23105    Zimbabwe
# 23106    Zimbabwe
# 23107    Zimbabwe
# 23108    Zimbabwe
# 23109    Zimbabwe
# Name: Country, Length: 23110, dtype: object

# %%
fprod['Year']
# Out:
# 0        2004
# 1        2005
# 2        2006
# 3        2007
# 4        2008
#          ...
# 23105    2009
# 23106    2010
# 23107    2011
# 23108    2012
# 23109    2013
# Name: Year, Length: 23110, dtype: int64

# %%
country_grp.agg(['median', 'mean'])
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_7444\3300990607.py:1: FutureWarning: ['Item', 'Value'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   country_grp.agg(['median', 'mean'])
#                                Year
#                              median         mean
# Country
# Algeria                      2008.5  2008.500000
# Angola                       2008.5  2008.500000
# Benin                        2008.5  2008.500000
# Botswana                     2008.5  2008.500000
# Burkina Faso                 2008.5  2008.500000
# Cabo Verde                   2008.5  2008.500000
# Cameroon                     2008.5  2008.500000
# Central African Republic     2008.5  2008.500000
# Chad                         2008.5  2008.500000
# Congo                        2008.5  2008.500000
# Cote d'Ivoire                2008.5  2008.500000
# Djibouti                     2008.5  2008.500000
# ...

# %%
fprod.groupby(['Country', 'Year', 'Item']).sum()
# Out:
#                                       Value
# Country  Year Item
# Algeria  2004 Apples and products     165kt
#               Bananas                   0kt
#               Barley and products    1212kt
#               Beans                     2kt
#               Beer                    110kt
# ...                                     ...
# Zimbabwe 2013 Tea (including mate)     19kt
#               Tomatoes and products    24kt
#               Vegetables, Other       203kt
#               Wheat and products       25kt
#               Wine                      2kt
#
# [23110 rows x 1 columns]

# %%
grp_sum=fprod.groupby(['Country', 'Year', 'Item']).sum()

# %%
grp_sum
# Out:
#                                       Value
# Country  Year Item
# Algeria  2004 Apples and products     165kt
#               Bananas                   0kt
#               Barley and products    1212kt
#               Beans                     2kt
#               Beer                    110kt
# ...                                     ...
# Zimbabwe 2013 Tea (including mate)     19kt
#               Tomatoes and products    24kt
#               Vegetables, Other       203kt
#               Wheat and products       25kt
#               Wine                      2kt
#
# [23110 rows x 1 columns]

# %%
from matplotlib import pyplot as plt 
import numpy as np
plt.plot(fprod['Country'], fprod['Year'] , color='g')

# %%
fprod.groupby(['Country'])

# %%
fprod.groupby(['Year'])
